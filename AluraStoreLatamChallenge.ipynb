# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #Exploración de datos

# %%
tienda.head()
tienda.info()
tienda.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
# ...

# %%
tienda2.head()
tienda2.info()
tienda2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
# ...

# %%
tienda2.head()
tienda2.info()
tienda2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
# ...

# %%
tienda4.head()
tienda4.info()
tienda4.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   object
#  1   Categoría del Producto  2358 non-null   object
#  2   Precio                  2358 non-null   float64
#  3   Costo de envío          2358 non-null   float64
#  4   Fecha de Compra         2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Lugar de Compra         2358 non-null   object
#  7   Calificación            2358 non-null   int64
#  8   Método de pago          2358 non-null   object
#  9   Cantidad de cuotas      2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
facturacion_t1 = tienda['Precio'].sum()
'Tienda 1 tiene una facturación total de $' + f"{facturacion_t1:,.0f}"
# Out:
# 'Tienda 1 tiene una facturación total de $1,150,880,400'

# %%
facturacion_t2 = tienda2['Precio'].sum()
'Tienda 2 tiene una facturación total de $' + f"{facturacion_t2:,.0f}"
# Out:
# 'Tienda 2 tiene una facturación total de $1,116,343,500'

# %%
facturacion_t3 = tienda3['Precio'].sum()
'Tienda 3 tiene una facturación total de $' + f"{facturacion_t3:,.0f}"
# Out:
# 'Tienda 3 tiene una facturación total de $1,098,019,600'

# %%
facturacion_t4 = tienda4['Precio'].sum()
'Tienda 4 tiene una facturación total de $' + f"{facturacion_t4:,.0f}"
# Out:
# 'Tienda 4 tiene una facturación total de $1,038,375,700'

# %% [markdown]
# # 2. Ventas por categoría

# %%
tienda['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
tienda2['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
tienda3['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
tienda4['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_t1 = tienda['Calificación'].mean()
'La calificación promedio de la Tienda 1 es de: ' + str(round(calificacion_t1, 2))
# Out:
# 'La calificación promedio de la Tienda 1 es de: 3.98'

# %%
calificacion_t2 = tienda2['Calificación'].mean()
'La calificación promedio de la Tienda 2 es de: ' + str(round(calificacion_t2, 2))
# Out:
# 'La calificación promedio de la Tienda 2 es de: 4.04'

# %%
calificacion_t3 = tienda3['Calificación'].mean()
'La calificación promedio de la Tienda 3 es de: ' + str(round(calificacion_t3, 2))
# Out:
# 'La calificación promedio de la Tienda 3 es de: 4.05'

# %%
calificacion_t4 = tienda4['Calificación'].mean()
'La calificación promedio de la Tienda 4 es de: ' + str(round(calificacion_t4, 2))
# Out:
# 'La calificación promedio de la Tienda 4 es de: 4.0'

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
productos_t1 = tienda['Producto'].value_counts().reset_index()
productos_t1.columns = ['Producto', 'Cantidad']
productos_t1.index = productos_t1.index + 1

# %%
'Los productos más vendidos han sido:'
productos_t1.head(5)
# Out:
#            Producto  Cantidad
# 1        Microondas        60
# 2     TV LED UHD 4K        60
# 3           Armario        60
# 4  Secadora de ropa        58
# 5     Mesa de noche        56

# %%
'Los productos menos vendidos han sido:'
productos_t1.tail(5)
# Out:
#                        Producto  Cantidad
# 47  Ciencia de datos con Python        39
# 48                    Pandereta        36
# 49              Olla de presión        35
# 50    Auriculares con micrófono        33
# 51                 Celular ABXY        33

# %%
productos_t2 = tienda2['Producto'].value_counts().reset_index()
productos_t2.columns = ['Producto', 'Cantidad']
productos_t2.index = productos_t2.index + 1

# %%
'Los productos más vendidos han sido:'
productos_t2.head(5)
# Out:
#                     Producto  Cantidad
# 1  Iniciando en programación        65
# 2                 Microondas        62
# 3                    Batería        61
# 4          Guitarra acústica        58
# 5                  Pandereta        58

# %%
'Los productos menos vendidos han sido:'
productos_t2.tail(5)
# Out:
#            Producto  Cantidad
# 47      Auriculares        37
# 48           Sillón        35
# 49  Mesa de comedor        34
# 50        Impresora        34
# 51    Juego de mesa        32

# %%
productos_t3 = tienda3['Producto'].value_counts().reset_index()
productos_t3.columns = ['Producto', 'Cantidad']
productos_t3.index = productos_t3.index + 1

# %%
'Los productos más vendidos han sido:'
productos_t3.head(5)
# Out:
#           Producto  Cantidad
# 1    Kit de bancas        57
# 2  Mesa de comedor        56
# 3        Cama king        56
# 4     Set de ollas        55
# 5    Mesa de noche        55

# %%
'Los productos menos vendidos han sido:'
productos_t3.tail(5)
# Out:
#                    Producto  Cantidad
# 47       Guitarra eléctrica        38
# 48             Set de vasos        36
# 49                  Mochila        36
# 50               Microondas        36
# 51  Bloques de construcción        35

# %%
productos_t4 = tienda4['Producto'].value_counts().reset_index()
productos_t4.columns = ['Producto', 'Cantidad']
productos_t4.index = productos_t4.index + 1

# %%
'Los productos más vendidos han sido:'
productos_t4.head(5)
# Out:
#                     Producto  Cantidad
# 1                   Cama box        62
# 2                 Cubertería        59
# 3    Dashboards con Power BI        56
# 4                  Cama king        56
# 5  Carrito de control remoto        55

# %%
'Los productos menos vendidos han sido:'
productos_t4.tail(5)
# Out:
#                        Producto  Cantidad
# 47                 Refrigerador        38
# 48  Ciencia de datos con Python        38
# 49            Guitarra acústica        37
# 50                      Armario        34
# 51           Guitarra eléctrica        33

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_t1 = tienda['Costo de envío'].mean()
'El costo de envío promedio de la Tienda 1 es de: $' + str(round(envio_t1, 2))
# Out:
# 'El costo de envío promedio de la Tienda 1 es de: $26018.61'

# %%
envio_t2 = tienda2['Costo de envío'].mean()
'El costo de envío promedio de la Tienda 2 es de: $' + str(round(envio_t2, 2))
# Out:
# 'El costo de envío promedio de la Tienda 2 es de: $25216.24'

# %%
envio_t3 = tienda3['Costo de envío'].mean()
'El costo de envío promedio de la Tienda 3 es de: $' + str(round(envio_t3, 2))
# Out:
# 'El costo de envío promedio de la Tienda 3 es de: $24805.68'

# %%
envio_t4 = tienda4['Costo de envío'].mean()
'El costo de envío promedio de la Tienda 4 es de: $' + str(round(envio_t4, 2))
# Out:
# 'El costo de envío promedio de la Tienda 4 es de: $23459.46'

# %% [markdown]
# #Visualización de datos en gráficos

# %% [markdown]
# ####Ingreso total por tienda

# %%
import matplotlib.pyplot as plt

tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
facturacion = [facturacion_t1, facturacion_t2, facturacion_t3, facturacion_t4]

plt.bar(tiendas, facturacion, color=['#4B8BBE', '#306998', '#FFE873', '#FFD43B'])
plt.title('Facturación total por tienda')
plt.xlabel('Tiendas')
plt.ylabel('Facturación ($)')
plt.show()

# %% [markdown]
# ####Calificación promedio por tienda

# %%
import matplotlib.pyplot as plt

tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
calificaciones = [calificacion_t1, calificacion_t2, calificacion_t3, calificacion_t4]

plt.barh(tiendas, calificaciones, color=['#77DD77', '#C3B1E1', '#A1CAF1', '#FFB347'])
plt.title('Calificación promedio por tienda')
plt.xlabel('Promedio de calificación')
plt.ylabel('Tienda')
plt.show()

# %% [markdown]
# ####Costo de envío promedio por tienda

# %%
import matplotlib.pyplot as plt

tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
envio = [envio_t1, envio_t2, envio_t3, envio_t4]

plt.plot(tiendas, envio, marker='o', color='#E67E22', linewidth=2)
plt.title('Costo de envío promedio por tienda')
plt.xlabel('Tienda')
plt.ylabel('Costo promedio ($)')
plt.grid(True)
plt.show()

# %% [markdown]
# #Extra – Análisis geográfico
#
# En esta sección se explora la distribución geográfica de las ventas a partir de las coordenadas de **latitud (lat)** y **longitud (lon)**.
# El objetivo es identificar concentraciones por ciudad y comparar cómo se reparten los ingresos entre las tiendas en los principales puntos de venta.

# %%
import pandas as pd

# Top 10 ciudades por facturación total
tot_ciudad = df_geo.groupby('Lugar de Compra')['Precio'].sum().sort_values(ascending=False)
top10_ciudades = tot_ciudad.head(10).index

# Tabla de ingresos por tienda a top 10
tabla_top10 = (
    df_geo[df_geo['Lugar de Compra'].isin(top10_ciudades)]
    .pivot_table(index='Lugar de Compra', columns='Tienda', values='Precio', aggfunc='sum', fill_value=0)
)

# Ciudades por volumen total
tabla_top10 = tabla_top10.loc[tabla_top10.sum(axis=1).sort_values(ascending=False).index]

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(8.2, 7.0))
plt.imshow(np.log1p(tabla_top10.values), cmap='PuRd', aspect='auto')

plt.xticks(np.arange(tabla_top10.shape[1]), tabla_top10.columns, fontsize=9)
plt.yticks(np.arange(tabla_top10.shape[0]), tabla_top10.index, fontsize=9)

for i in range(tabla_top10.shape[0]):
    for j in range(tabla_top10.shape[1]):
        v = tabla_top10.values[i, j]
        if v >= 1_000_000:
            t = f"{v/1_000_000:.1f}M"
        elif v >= 1_000:
            t = f"{v/1_000:.0f}K"
        else:
            t = f"{int(v)}"
        plt.text(j, i, t, ha='center', va='center', fontsize=8, color='black')

plt.title("Top 10 ciudades por facturación – Ingresos por tienda")
plt.xlabel("Tienda")
plt.ylabel("Ciudad")
plt.colorbar(label='Escala log(1 + ingresos)')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plot_df = (
    df_geo[df_geo['Lugar de Compra'].isin(top10_ciudades)]
    .groupby('Lugar de Compra', as_index=False)
    .agg(Precio=('Precio','sum'),
         lat=('lat','median'),
         lon=('lon','median'))
)

s = (plot_df['Precio'] / plot_df['Precio'].max()) * 1800
s = np.maximum(s, 80)

fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(
    plot_df['lon'], plot_df['lat'],
    s=s, alpha=0.55,
    color='#92456A', edgecolors='#2b1a25', linewidths=0.8
)

for _, r in plot_df.iterrows():
    ax.text(r['lon'] + 0.06, r['lat'] + 0.06, r['Lugar de Compra'], fontsize=8.5, color='#1e0f16')

ax.set_title('Top 10 ciudades por facturación – Distribución geográfica de ingresos')
ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')
ax.grid(True, linestyle='--', linewidth=0.4, alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretación del análisis geográfico
#
# El gráfico de dispersión muestra la distribución geográfica de las ventas registradas por las cuatro tiendas.
# Las coordenadas de latitud y longitud evidencian que las transacciones se concentran principalmente en las principales regiones urbanas del país, como Bogotá, Medellín y Cali, con una distribución muy similar entre todas las tiendas.
#
# No se observan diferencias significativas en la ubicación de los clientes que expliquen los contrastes en ventas o calificaciones.
# Por lo tanto, se concluye que la variable geográfica no influye directamente en el desempeño: los resultados dependen de factores internos, como la gestión comercial, las categorías de productos y la experiencia de compra.

# %% [markdown]
# #Informe Final

# %% [markdown]
# ##Índice de desempeño y recomendación final

# %%
#Metricas por tienda
import pandas as pd

resumen = pd.DataFrame({
    'Tienda': ['Tienda 1','Tienda 2','Tienda 3','Tienda 4'],
    'Ingreso': [
        tienda['Precio'].sum(),
        tienda2['Precio'].sum(),
        tienda3['Precio'].sum(),
        tienda4['Precio'].sum()
    ],
    'Calificación': [
        tienda['Calificación'].mean(),
        tienda2['Calificación'].mean(),
        tienda3['Calificación'].mean(),
        tienda4['Calificación'].mean()
    ],
    'EnvioProm': [
        tienda['Costo de envío'].mean(),
        tienda2['Costo de envío'].mean(),
        tienda3['Costo de envío'].mean(),
        tienda4['Costo de envío'].mean()
    ],
    'Ventas': [
        tienda['Producto'].count(),
        tienda2['Producto'].count(),
        tienda3['Producto'].count(),
        tienda4['Producto'].count()
    ]
})

resumen
# Out:
#      Tienda       Ingreso  Calificación     EnvioProm  Ventas
# 0  Tienda 1  1.150880e+09      3.976685  26018.609580    2359
# 1  Tienda 2  1.116344e+09      4.037304  25216.235693    2359
# 2  Tienda 3  1.098020e+09      4.048326  24805.680373    2359
# 3  Tienda 4  1.038376e+09      3.995759  23459.457167    2358

# %%
#Normalización + Índice de desempeño
df = resumen.copy()

for col in ['Ingreso', 'Calificación', 'Ventas']:
    df[col + '_Norm'] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())

df['EnvioProm_Norm'] = (df['EnvioProm'].max() - df['EnvioProm']) / (df['EnvioProm'].max() - df['EnvioProm'].min())
df['IndiceDesempeño'] = df[['Ingreso_Norm','Calificación_Norm','Ventas_Norm','EnvioProm_Norm']].mean(axis=1)
df_ordenado = df.sort_values('IndiceDesempeño', ascending=False).reset_index(drop=True)
df_ordenado[['Tienda','Ingreso','Calificación','EnvioProm','Ventas','IndiceDesempeño']]
# Out:
#      Tienda       Ingreso  Calificación     EnvioProm  Ventas  IndiceDesempeño
# 0  Tienda 3  1.098020e+09      4.048326  24805.680373    2359         0.751026
# 1  Tienda 2  1.116344e+09      4.037304  25216.235693    2359         0.713176
# 2  Tienda 1  1.150880e+09      3.976685  26018.609580    2359         0.500000
# 3  Tienda 4  1.038376e+09      3.995759  23459.457167    2358         0.316562

# %%
# Peor desempeño
df.loc[df['IndiceDesempeño'].idxmin(), ['Tienda','IndiceDesempeño']]
# Out:
# Tienda             Tienda 4
# IndiceDesempeño    0.316562
# Name: 3, dtype: object

# %%
tienda_cerrar = df.loc[df['IndiceDesempeño'].idxmin(), 'Tienda']
pd.DataFrame({'Recomendación': [ 'Vender ' + tienda_cerrar + ' (menor índice de desempeño).' ]})
# Out:
#                                   Recomendación
# 0  Vender Tienda 4 (menor índice de desempeño).

# %% [markdown]
# ## Recomendación para el Sr. Juan
#
# ### Introducción
# El presente informe resume el análisis de desempeño de las cuatro tiendas de la cadena Alura Store, con el objetivo de determinar cuál de ellas debería ser vendida para que el Sr. Juan pueda invertir en un nuevo proyecto.
#
# El estudio se basó en cinco indicadores clave:
# - Facturación total
# - Categorías y productos más vendidos
# - Calificación promedio de clientes
# - Costo de envío promedio
# - Índice de desempeño general (combinando métricas normalizadas)
#
# ---
#
# ### Análisis de resultados
#
# #### Facturación total
# La **Tienda 1** registró el mayor nivel de ingresos con aproximadamente `$1.150.880.400`,
# mientras que la **Tienda 4** fue la de menor facturación con `$1.038.375.700`.
# Esto demuestra una diferencia importante en el rendimiento económico entre ambas.
#
# #### Calificación promedio
# Las calificaciones oscilaron entre `3.97` y `4.05`.
# Las **Tiendas 2 y 3** obtuvieron las mejores valoraciones por parte de los clientes,
# mientras que la **Tienda 1** presentó la calificación más baja.
#
# #### Costo de envío promedio
# El costo de envío fue un factor relevante:
# la **Tienda 4** presentó el valor promedio más bajo (`$23.459,46`),
# mientras que la **Tienda 1** registró el más alto (`$26.018,61`).
# Aunque la Tienda 4 posee costos de envío competitivos,
# su bajo volumen de ingresos y ventas afecta su rendimiento general.
#
# #### Índice de desempeño general
# Al combinar los indicadores de ingresos, calificación, ventas y costos de envío,
# se calculó un **Índice de Desempeño Normalizado**.
# Este índice permite comparar objetivamente la eficiencia global de cada tienda:
#
# | Tienda | Índice de Desempeño |
# |:-------|--------------------:|
# | Tienda 3 | 0.75 |
# | Tienda 2 | 0.71 |
# | Tienda 1 | 0.50 |
# | Tienda 4 | 0.32 |
#
# ---
#
# ### Conclusión
# De acuerdo con los resultados obtenidos, la **Tienda 4** presenta el menor índice de desempeño (`0.32`),
# lo que refleja un rendimiento inferior en comparación con las demás tiendas.
#
# Si bien cuenta con costos de envío bajos, sus ingresos y ventas totales son los más reducidos,
# lo que disminuye su rentabilidad global.
#
# Por lo tanto, se recomienda **vender la Tienda 4**,
# ya que es la menos rentable del grupo y su desempeño general la posiciona como la mejor opción para desprenderse de ella.
#
# ---
#
# **Cordialmente,**
# **Alberto Edgardo Villalba**
